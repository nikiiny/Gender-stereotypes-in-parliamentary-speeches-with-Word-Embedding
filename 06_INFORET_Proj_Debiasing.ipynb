# %% [markdown]
# # INFORMATION RETRIEVAL PROJECT
# # 6. WORDS DEBIASING

# %% [markdown]
# ---
# ## Gender stereotypes in parliamentary speeches
#
# In word embedding models, each word is assigned to a high-dimensional vector such that the geometry of the vectors captures semantic relations between the words – e.g. vectors being closer together has been shown to correspond to more similar words. Recent works in machine learning demonstrate that word embeddings also capture common stereotypes, as these stereotypes are likely to be present, even if subtly, in the large corpora of training texts. These stereotypes are automatically learned by the embedding algorithm and could be problematic in many context if the embedding is then used for sensitive applications such as search rankings, product recommendations, or translations. An important direction of research is on developing algorithms to debias the word embeddings.
#
# This project aims to use the word embeddings to study historical trends – specifically trends in the gender and ethnic stereotypes in the Italian parliamentary speeches from 1948 to 2020.

# %%
import numpy as np
import pandas as pd
import gensim
from gensim.models import KeyedVectors
from gensim.models import Word2Vec
import os
from collections import defaultdict, OrderedDict
from tqdm.auto import tqdm

from INFORET_project import load_embed_model
# import matplotlib.pylab as plt
pd.set_option("display.max_rows", 100, "display.max_columns", 100)

# %%
from INFORET_project import YEARS

# %%
YEARS
# Out:
# ['1948_1968', '1968_1985', '1985_2000', '2000_2020']

# %%
model = load_embed_model(YEARS[0])

# %%
model = load_embed_model(YEARS[1])

# %%
model = load_embed_model(YEARS[2])

# %%
model = load_embed_model(YEARS[3])

# %% [markdown]
# ---

# %% [markdown]
# Use bolukbasi hard debiasing algorithm to remove gender stereotypes. Try different ways to compute the gender direction: single, sum and pca.

# %%
from INFORET_project import Debias
from INFORET_project.data import gendered_neutral_words

# %%
d = Debias(model.wv, definitional_pairs=['uomo','donna'],
                              identify_direction='single')
debiased_model_single = d.hard_debias(equality_sets=gendered_neutral_words['equality_sets'])

# %%
debiased_model_single

# %%
d = Debias(model.wv, definitional_pairs=['uomo','donna'],
                              identify_direction='sum')
debiased_model_sum = d.hard_debias(equality_sets=gendered_neutral_words['equality_sets'])

# %%
debiased_model_sum

# %%
d = Debias(model.wv, definitional_pairs=['uomo','donna'], identify_direction='pca')
debiased_model_pca = d.hard_debias(equality_sets=gendered_neutral_words['equality_sets'])

# %%
debiased_model_pca

# %% [markdown]
# ---

# %% [markdown]
# Use EAB to see whether the hard debiasing reduces the bias within the language.
#
# Apply EAB on word2vec models before and after the debisaing. Print only the top biased word to see whether the bias is reduced

# %%
from INFORET_project.data import gendered_neutral_words
from INFORET_project import EAB
from INFORET_project import WORDS_GROUP

# %%
# print the top biased word of each group of words for EAB with averaged gendered vectors, before and 
#after debiasing

for year in tqdm(YEARS,
                 desc='Passing years'):
    print(f'\nYEAR: {year}')
    model = load_embed_model(year)
    
    for word in tqdm(WORDS_GROUP,
                     desc='Passing group of words'):
        print(f'\n\nGROUP OF WORDS: {word}\n')

        print('\nMODEL: Not debiased model')
        score = EAB(model.wv,
                    use_avg_gender=True,
                    type_most_similar = 'cosmul')
        # return only the top biased word for each group of words
        top_bias = score.get_top_bias(pred_positive_word=word, verbose=False)[0]
        # print the word and the total bias (difference of the cosine similarities btw words
        #returned by the analogy and genders)
        print( (top_bias[0], abs(top_bias[1][0] - top_bias[1][1])) )
        
        for deb_type in ['single', 'sum', 'pca']:
            d = Debias(model.wv, definitional_pairs=['uomo','donna'],
                              identify_direction=deb_type)
            # return debiased word2vec model
            debiased_model = d.hard_debias(equality_sets=gendered_neutral_words['equality_sets'])
            
            score = EAB(debiased_model,
                        use_avg_gender=True,
                        type_most_similar = 'cosmul')
            print(f'\nMODEL: Debiased model {deb_type}')
            top_bias = score.get_top_bias(pred_positive_word=word, verbose=False)[0]
            print( (top_bias[0], abs(top_bias[1][0] - top_bias[1][1])) )
# Out:
# HBox(children=(HTML(value='Passing years'), FloatProgress(value=0.0, max=4.0), HTML(value='')))
# YEAR: 1948_1968
# HBox(children=(HTML(value='Passing group of words'), FloatProgress(value=0.0, max=12.0), HTML(value='')))
# GROUP OF WORDS: adj_appearence
#
#
# MODEL: Not debiased model
# ('grasso', 0.06127673238515857)
#
# MODEL: Debiased model single
# ('splendido', 0.32155335918068884)
#
# MODEL: Debiased model sum
# ('splendido', 0.04324311316013335)
#
# MODEL: Debiased model pca
# ('brutto', 0.3194217950105668)
#
#
# GROUP OF WORDS: family
#
#
# MODEL: Not debiased model
# ('bambino', 0.04381868690252305)
#
# MODEL: Debiased model single
# ('figlio', 0.2617485515773296)
#
# MODEL: Debiased model sum
# ('matrimonio', 0.03625070452690127)
#
# MODEL: Debiased model pca
# ('bambino', 0.294831258803606)
#
#
# GROUP OF WORDS: career
#
#
# MODEL: Not debiased model
# ('capo', 0.0394399270415306)
#
# MODEL: Debiased model single
# ('capo', 0.3804219402372837)
#
# MODEL: Debiased model sum
# ('capo', 0.03289711177349092)
#
# MODEL: Debiased model pca
# ('capo', 0.3760174781084061)
#
#
# GROUP OF WORDS: rage
#
#
# MODEL: Not debiased model
# ('aggressivo', 0.0696475218981504)
#
# MODEL: Debiased model single
# ('cattivo', 0.3830927975475788)
#
# MODEL: Debiased model sum
# ('crudele', 0.040964144468307484)
#
# MODEL: Debiased model pca
# ('cattivo', 0.373015633225441)
#
#
# GROUP OF WORDS: kindness
#
#
# MODEL: Not debiased model
# ('bravo', 0.008589015901088737)
#
# MODEL: Debiased model single
# ('bravo', 0.29184717759490014)
#
# MODEL: Debiased model sum
# ('gentile', 0.05670201778411865)
#
# MODEL: Debiased model pca
# ('buono', 0.37231014221906666)
#
#
# GROUP OF WORDS: intelligence
#
#
# MODEL: Not debiased model
# ('studioso', 0.013190972805023238)
#
# MODEL: Debiased model single
# ('intelligente', 0.37070150300860405)
#
# MODEL: Debiased model sum
# ('intelligente', 0.04211550354957583)
#
# MODEL: Debiased model pca
# ('razionale', 0.3362434238195419)
#
#
# GROUP OF WORDS: dumbness
#
#
# MODEL: Not debiased model
# ('isterico', 0.010038386285305012)
#
# MODEL: Debiased model single
# ('isterico', 0.33778637275099754)
#
# MODEL: Debiased model sum
# ('illogico', 0.0045525252819060835)
#
# MODEL: Debiased model pca
# ('stupido', 0.3393777266144753)
#
#
# GROUP OF WORDS: active
#
#
# MODEL: Not debiased model
# ('ambizioso', 0.03679673746228218)
#
# MODEL: Debiased model single
# ('forte', 0.3482457108795643)
#
# MODEL: Debiased model sum
# ('sicuro', 0.015118518471717801)
#
# MODEL: Debiased model pca
# ('sicuro', 0.34583647698163983)
#
#
# GROUP OF WORDS: passive
#
#
# MODEL: Not debiased model
# ('silenzioso', 0.007643775641918149)
#
# MODEL: Debiased model single
# ('silenzioso', 0.36557785198092463)
#
# MODEL: Debiased model sum
# ('silenzioso', 0.07729616463184358)
#
# MODEL: Debiased model pca
# ('timido', 0.37549301981925964)
#
#
# GROUP OF WORDS: gendered_words
#
#
# MODEL: Not debiased model
# ('maschile', 0.05958382487297059)
#
# MODEL: Debiased model single
# ('nonna', 0.03350709825754167)
#
# MODEL: Debiased model sum
# ('ragazza', 0.016883930563926675)
#
# MODEL: Debiased model pca
# ('nonna', 0.005105347931385118)
#
#
# GROUP OF WORDS: female_stereotypes
#
#
# MODEL: Not debiased model
# ('silenzioso', 0.007643775641918149)
#
# MODEL: Debiased model single
# ('silenzioso', 0.36557785198092463)
#
# MODEL: Debiased model sum
# ('gentile', 0.05670201778411865)
#
# MODEL: Debiased model pca
# ('gentile', 0.32287739738821986)
#
#
# GROUP OF WORDS: male_stereotypes
#
#
# MODEL: Not debiased model
# ('intelligente', 0.04734245315194127)
#
# MODEL: Debiased model single
# ('intelligente', 0.37070150300860405)
#
# MODEL: Debiased model sum
# ('intelligente', 0.04211550354957583)
#
# MODEL: Debiased model pca
# ('crudele', 0.3215011708438396)
#
#
# YEAR: 1968_1985
# HBox(children=(HTML(value='Passing group of words'), FloatProgress(value=0.0, max=12.0), HTML(value='')))
# GROUP OF WORDS: adj_appearence
#
#
# MODEL: Not debiased model
# ('sensuale', 0.03292045444250108)
#
# MODEL: Debiased model single
# ('bello', 0.37385801970958715)
#
# MODEL: Debiased model sum
# ('bello', 0.04820239841938018)
#
# MODEL: Debiased model pca
# ('brutto', 0.015571779012680087)
#
#
# GROUP OF WORDS: family
#
#
# MODEL: Not debiased model
# ('bambino', 0.05103850066661836)
#
# MODEL: Debiased model single
# ('figlio', 0.3037390366196633)
#
# MODEL: Debiased model sum
# ('bambino', 0.022042566537857022)
#
# MODEL: Debiased model pca
# ('accudire', 0.0025791302323340815)
#
#
# GROUP OF WORDS: career
#
#
# MODEL: Not debiased model
# ('presidente', 0.04962961599230764)
#
# MODEL: Debiased model single
# ('professionale', 0.37142196595668797)
#
# MODEL: Debiased model sum
# ('onorevole', 0.018504664301872253)
#
# MODEL: Debiased model pca
# ('onorevole', 0.014784026145935103)
#
#
# GROUP OF WORDS: rage
#
#
# MODEL: Not debiased model
# ('intollerante', 0.0602129846811294)
#
# MODEL: Debiased model single
# ('crudele', 0.3755185320973397)
#
# MODEL: Debiased model sum
# ('crudele', 0.03154923617839811)
#
# MODEL: Debiased model pca
# ('crudele', 0.027835524082183816)
#
#
# GROUP OF WORDS: kindness
#
#
# MODEL: Not debiased model
# ('bravo', 0.03786450028419491)
#
# MODEL: Debiased model single
# ('bravo', 0.3855606362223626)
#
# MODEL: Debiased model sum
# ('gentile', 0.043447837233543396)
#
# MODEL: Debiased model pca
# ('gentile', 0.01941621005535127)
#
#
# GROUP OF WORDS: intelligence
#
#
# MODEL: Not debiased model
# ('studioso', 0.03357839286327363)
#
# MODEL: Debiased model single
# ('studioso', 0.3739052012562752)
#
# MODEL: Debiased model sum
# ('intelligente', 0.014818078279495273)
#
# MODEL: Debiased model pca
# ('intelligente', 0.006855869293212857)
#
#
# GROUP OF WORDS: dumbness
#
#
# MODEL: Not debiased model
# ('stupido', 0.05983314961194991)
#
# MODEL: Debiased model single
# ('isterico', 0.383736239373684)
#
# MODEL: Debiased model sum
# ('illogico', 0.004470849037170432)
#
# MODEL: Debiased model pca
# ('isterico', 0.00011099129915237427)
#
#
# GROUP OF WORDS: active
#
#
# MODEL: Not debiased model
# ('ambizioso', 0.06336533427238467)
#
# MODEL: Debiased model single
# ('forte', 0.39403597265481954)
#
# MODEL: Debiased model sum
# ('sicuro', 0.003371769189834617)
#
# MODEL: Debiased model pca
# ('sicuro', 0.01237705647945403)
#
#
# GROUP OF WORDS: passive
#
#
# MODEL: Not debiased model
# ('insicuro', 0.03633227422833446)
#
# MODEL: Debiased model single
# ('debole', 0.3803715243935586)
#
# MODEL: Debiased model sum
# ('silenzioso', 0.026003092527389582)
#
# MODEL: Debiased model pca
# ('silenzioso', 0.01870554387569423)
#
#
# GROUP OF WORDS: gendered_words
#
#
# MODEL: Not debiased model
# ('madre', 0.08406004607677459)
#
# MODEL: Debiased model single
# ('nonno', 0.03935730159282691)
#
# MODEL: Debiased model sum
# ('nonna', 0.0)
#
# MODEL: Debiased model pca
# ('maschile', 0.0058301836252212524)
#
#
# GROUP OF WORDS: female_stereotypes
#
#
# MODEL: Not debiased model
# ('frivolo', 0.054298542439937536)
#
# MODEL: Debiased model single
# ('bello', 0.37385801970958715)
#
# MODEL: Debiased model sum
# ('gentile', 0.043447837233543396)
#
# MODEL: Debiased model pca
# ('gentile', 0.01941621005535127)
#
#
# GROUP OF WORDS: male_stereotypes
#
#
# MODEL: Not debiased model
# ('intollerante', 0.0602129846811294)
#
# MODEL: Debiased model single
# ('crudele', 0.3755185320973397)
#
# MODEL: Debiased model sum
# ('intelligente', 0.014818078279495273)
#
# MODEL: Debiased model pca
# ('intelligente', 0.006855869293212857)
#
#
# YEAR: 1985_2000
# HBox(children=(HTML(value='Passing group of words'), FloatProgress(value=0.0, max=12.0), HTML(value='')))
# GROUP OF WORDS: adj_appearence
#
#
# MODEL: Not debiased model
# ('frivolo', 0.06346932649612425)
#
# MODEL: Debiased model single
# ('grasso', 0.39070465769618745)
#
# MODEL: Debiased model sum
# ('bello', 0.021702119708061185)
#
# MODEL: Debiased model pca
# ('grasso', 0.3305662658065558)
#
#
# GROUP OF WORDS: family
#
#
# MODEL: Not debiased model
# ('bambino', 0.025714072585105885)
#
# MODEL: Debiased model single
# ('famiglia', 0.3732928760349751)
#
# MODEL: Debiased model sum
# ('genitore', 0.005285957455635093)
#
# MODEL: Debiased model pca
# ('famiglia', 0.3127041898667812)
#
#
# GROUP OF WORDS: career
#
#
# MODEL: Not debiased model
# ('capo', 0.012652518227696419)
#
# MODEL: Debiased model single
# ('onorevole', 0.3628251388669014)
#
# MODEL: Debiased model sum
# ('carriera', 0.02822107672691343)
#
# MODEL: Debiased model pca
# ('professionale', 0.3292255993932486)
#
#
# GROUP OF WORDS: rage
#
#
# MODEL: Not debiased model
# ('cattivo', 0.04554537683725357)
#
# MODEL: Debiased model single
# ('brutale', 0.40178558081388477)
#
# MODEL: Debiased model sum
# ('crudele', 0.026416066288948048)
#
# MODEL: Debiased model pca
# ('crudele', 0.33064295314252373)
#
#
# GROUP OF WORDS: kindness
#
#
# MODEL: Not debiased model
# ('bravo', 0.08703152537345887)
#
# MODEL: Debiased model single
# ('delicato', 0.42523160781711333)
#
# MODEL: Debiased model sum
# ('gentile', 0.020900794863700833)
#
# MODEL: Debiased model pca
# ('premuroso', 0.31487809382379056)
#
#
# GROUP OF WORDS: intelligence
#
#
# MODEL: Not debiased model
# ('studioso', 0.12164089828729627)
#
# MODEL: Debiased model single
# ('studioso', 0.4191254906356335)
#
# MODEL: Debiased model sum
# ('studioso', 0.026938623189926125)
#
# MODEL: Debiased model pca
# ('saggio', 0.32061161361634727)
#
#
# GROUP OF WORDS: dumbness
#
#
# MODEL: Not debiased model
# ('stupido', 0.018399919569492273)
#
# MODEL: Debiased model single
# ('stupido', 0.41183152645826343)
#
# MODEL: Debiased model sum
# ('superficiale', 0.0037499576807022428)
#
# MODEL: Debiased model pca
# ('stupido', 0.347070300206542)
#
#
# GROUP OF WORDS: active
#
#
# MODEL: Not debiased model
# ('sicuro', 0.03558809757232667)
#
# MODEL: Debiased model single
# ('sicuro', 0.4191541835665703)
#
# MODEL: Debiased model sum
# ('sicuro', 0.01042993664741515)
#
# MODEL: Debiased model pca
# ('forte', 0.35637904964387424)
#
#
# GROUP OF WORDS: passive
#
#
# MODEL: Not debiased model
# ('passivo', 0.03018939048051833)
#
# MODEL: Debiased model single
# ('debole', 0.40099308341741563)
#
# MODEL: Debiased model sum
# ('insicuro', 0.009884718060493514)
#
# MODEL: Debiased model pca
# ('debole', 0.34332053326070305)
#
#
# GROUP OF WORDS: gendered_words
#
#
# MODEL: Not debiased model
# ('ragazza', 0.02867603600025176)
#
# MODEL: Debiased model single
# ('nonno', 0.006641458161175229)
#
# MODEL: Debiased model sum
# ('ragazza', 0.0)
#
# MODEL: Debiased model pca
# ('nonno', 0.0)
#
#
# GROUP OF WORDS: female_stereotypes
#
#
# MODEL: Not debiased model
# ('passivo', 0.03018939048051833)
#
# MODEL: Debiased model single
# ('debole', 0.40099308341741563)
#
# MODEL: Debiased model sum
# ('bello', 0.021702119708061185)
#
# MODEL: Debiased model pca
# ('debole', 0.34332053326070305)
#
#
# GROUP OF WORDS: male_stereotypes
#
#
# MODEL: Not debiased model
# ('razionale', 0.050117566436529176)
#
# MODEL: Debiased model single
# ('intollerante', 0.403975622355938)
#
# MODEL: Debiased model sum
# ('crudele', 0.026416066288948048)
#
# MODEL: Debiased model pca
# ('saggio', 0.32061161361634727)
#
#
# YEAR: 2000_2020
# HBox(children=(HTML(value='Passing group of words'), FloatProgress(value=0.0, max=12.0), HTML(value='')))
# GROUP OF WORDS: adj_appearence
#
#
# MODEL: Not debiased model
# ('brutto', 0.03416837677359583)
#
# MODEL: Debiased model single
# ('bello', 0.3236428740434349)
#
# MODEL: Debiased model sum
# ('splendido', 0.07683547586202621)
#
# MODEL: Debiased model pca
# ('bello', 0.6495590589009226)
#
#
# GROUP OF WORDS: family
#
#
# MODEL: Not debiased model
# ('bambino', 0.03165259659290315)
#
# MODEL: Debiased model single
# ('famiglia', 0.37531661717221143)
#
# MODEL: Debiased model sum
# ('matrimonio', 0.056497968733310755)
#
# MODEL: Debiased model pca
# ('genitore', 0.6651592994108796)
#
#
# GROUP OF WORDS: career
#
#
# MODEL: Not debiased model
# ('capo', 0.0712145067751408)
#
# MODEL: Debiased model single
# ('onorevole', 0.37300224630162115)
#
# MODEL: Debiased model sum
# ('presidente', 0.02160630375146866)
#
# MODEL: Debiased model pca
# ('professionale', 0.715283754747361)
#
#
# GROUP OF WORDS: rage
#
#
# MODEL: Not debiased model
# ('intollerante', 0.058555851876735676)
#
# MODEL: Debiased model single
# ('brutale', 0.42053920058533545)
#
# MODEL: Debiased model sum
# ('brutale', 0.055206632614135775)
#
# MODEL: Debiased model pca
# ('brutale', 0.7121246091090143)
#
#
# GROUP OF WORDS: kindness
#
#
# MODEL: Not debiased model
# ('premuroso', 0.08352464735507958)
#
# MODEL: Debiased model single
# ('bravo', 0.40868852017447355)
#
# MODEL: Debiased model sum
# ('gentile', 0.013186347484588634)
#
# MODEL: Debiased model pca
# ('gentile', 0.6419188587926328)
#
#
# GROUP OF WORDS: intelligence
#
#
# MODEL: Not debiased model
# ('studioso', 0.08405009955167772)
#
# MODEL: Debiased model single
# ('intelligente', 0.42122530890628695)
#
# MODEL: Debiased model sum
# ('saggio', 0.04634193181991575)
#
# MODEL: Debiased model pca
# ('studioso', 0.7248481045477092)
#
#
# GROUP OF WORDS: dumbness
#
#
# MODEL: Not debiased model
# ('stupido', 0.014228223264217355)
#
# MODEL: Debiased model single
# ('stupido', 0.41743476195260887)
#
# MODEL: Debiased model sum
# ('illogico', 0.007067242264747642)
#
# MODEL: Debiased model pca
# ('superficiale', 0.7204814172349869)
#
#
# GROUP OF WORDS: active
#
#
# MODEL: Not debiased model
# ('assertivo', 0.049580627679824796)
#
# MODEL: Debiased model single
# ('sicuro', 0.4287715937010944)
#
# MODEL: Debiased model sum
# ('sicuro', 0.011618122458458002)
#
# MODEL: Debiased model pca
# ('forte', 0.7239338359795511)
#
#
# GROUP OF WORDS: passive
#
#
# MODEL: Not debiased model
# ('insicuro', 0.07787061333656306)
#
# MODEL: Debiased model single
# ('insicuro', 0.41573864994570614)
#
# MODEL: Debiased model sum
# ('insicuro', 0.049501270055770874)
#
# MODEL: Debiased model pca
# ('insicuro', 0.6888584203086794)
#
#
# GROUP OF WORDS: gendered_words
#
#
# MODEL: Not debiased model
# ('femminile', 0.030746971070766405)
#
# MODEL: Debiased model single
# ('nonna', 0.0)
#
# MODEL: Debiased model sum
# ('nonno', 0.0)
#
# MODEL: Debiased model pca
# ('nonna', 0.0)
#
#
# GROUP OF WORDS: female_stereotypes
#
#
# MODEL: Not debiased model
# ('insicuro', 0.07787061333656306)
#
# MODEL: Debiased model single
# ('bello', 0.3236428740434349)
#
# MODEL: Debiased model sum
# ('gentile', 0.013186347484588634)
#
# MODEL: Debiased model pca
# ('gentile', 0.6419188587926328)
#
#
# GROUP OF WORDS: male_stereotypes
#
#
# MODEL: Not debiased model
# ('intollerante', 0.058555851876735676)
#
# MODEL: Debiased model single
# ('intollerante', 0.42036879388615495)
#
# MODEL: Debiased model sum
# ('saggio', 0.04634193181991575)
#
# MODEL: Debiased model pca
# ('crudele', 0.7140499061904847)

# %%
# print the top biased word of each group of words for EAB without averaged gendered vectors, before and 
#after debiasing


for year in tqdm(YEARS,
                 desc='Passing years'):
    print(f'\nYEAR: {year}')
    model = load_embed_model(year)
    
    for word in tqdm(WORDS_GROUP,
                     desc='Passing group of words'):
        print(f'\n\nGROUP OF WORDS: {word}\n')

        print('\nMODEL: Not debiased model')
        score = EAB(model.wv,
                    gender_female='donna',
                    gender_male='uomo',
                    type_most_similar = 'cosmul')
        top_bias = score.get_top_bias(pred_positive_word=word, verbose=False)[0]
        print( (top_bias[0], abs(top_bias[1][0] - top_bias[1][1])) )
        
        for deb_type in ['single', 'sum', 'pca']:
            d = Debias(model.wv, definitional_pairs=['uomo','donna'],
                              identify_direction=deb_type)
            debiased_model = d.hard_debias(equality_sets=gendered_neutral_words['equality_sets'])
            
            score = EAB(debiased_model,
                        gender_female='donna',
                        gender_male='uomo',
                        type_most_similar = 'cosmul')
            print(f'\nMODEL: Debiased model {deb_type}')
            top_bias = score.get_top_bias(pred_positive_word=word, verbose=False)[0]
            print( (top_bias[0], abs(top_bias[1][0] - top_bias[1][1])) )
# Out:
# HBox(children=(HTML(value='Passing years'), FloatProgress(value=0.0, max=4.0), HTML(value='')))
# YEAR: 1948_1968
# HBox(children=(HTML(value='Passing group of words'), FloatProgress(value=0.0, max=12.0), HTML(value='')))
# GROUP OF WORDS: adj_appearence
#
#
# MODEL: Not debiased model
# ('brutto', 0.02924209404736755)
#
# MODEL: Debiased model single
# ('splendido', 0.008128891512751646)
#
# MODEL: Debiased model sum
# ('splendido', 0.011958493106067225)
#
# MODEL: Debiased model pca
# ('rozzo', 0.03843159824609754)
#
#
# GROUP OF WORDS: family
#
#
# MODEL: Not debiased model
# ('accudire', 0.10531398877501488)
#
# MODEL: Debiased model single
# ('accudire', 0.0032697383314370665)
#
# MODEL: Debiased model sum
# ('accudire', 0.016254047863185406)
#
# MODEL: Debiased model pca
# ('accudire', 0.040101695060730025)
#
#
# GROUP OF WORDS: career
#
#
# MODEL: Not debiased model
# ('ambizione', 0.033331044763326656)
#
# MODEL: Debiased model single
# ('denaro', 0.008128891512751646)
#
# MODEL: Debiased model sum
# ('potere', 0.014785196445882276)
#
# MODEL: Debiased model pca
# ('capo', 0.03843159824609754)
#
#
# GROUP OF WORDS: rage
#
#
# MODEL: Not debiased model
# ('crudele', 0.02310821935534474)
#
# MODEL: Debiased model single
# ('aggressivo', 0.005208798125386327)
#
# MODEL: Debiased model sum
# ('aggressivo', 0.014785196445882276)
#
# MODEL: Debiased model pca
# ('intollerante', 0.03843159824609754)
#
#
# GROUP OF WORDS: kindness
#
#
# MODEL: Not debiased model
# ('gentile', 0.03569187410175795)
#
# MODEL: Debiased model single
# ('gentile', 0.008128891512751646)
#
# MODEL: Debiased model sum
# ('buono', 0.014785196445882276)
#
# MODEL: Debiased model pca
# ('sensibile', 0.03843159824609754)
#
#
# GROUP OF WORDS: intelligence
#
#
# MODEL: Not debiased model
# ('saggio', 0.020320691261440482)
#
# MODEL: Debiased model single
# ('saggio', 0.005208798125386327)
#
# MODEL: Debiased model sum
# ('intelligente', 0.020697664283215955)
#
# MODEL: Debiased model pca
# ('intelligente', 0.04223394356667998)
#
#
# GROUP OF WORDS: dumbness
#
#
# MODEL: Not debiased model
# ('isterico', 0.0804755762219429)
#
# MODEL: Debiased model single
# ('isterico', 0.008128891512751646)
#
# MODEL: Debiased model sum
# ('isterico', 0.016254041157662935)
#
# MODEL: Debiased model pca
# ('irrazionale', 0.03843159824609754)
#
#
# GROUP OF WORDS: active
#
#
# MODEL: Not debiased model
# ('ambizioso', 0.023078519944101594)
#
# MODEL: Debiased model single
# ('sicuro', 0.006096723303198881)
#
# MODEL: Debiased model sum
# ('sicuro', 0.014785196445882276)
#
# MODEL: Debiased model pca
# ('forte', 0.03843159824609754)
#
#
# GROUP OF WORDS: passive
#
#
# MODEL: Not debiased model
# ('silenzioso', 0.01594360191375016)
#
# MODEL: Debiased model single
# ('silenzioso', 0.007240966334939092)
#
# MODEL: Debiased model sum
# ('timido', 0.01869779881089917)
#
# MODEL: Debiased model pca
# ('timido', 0.03843159824609754)
#
#
# GROUP OF WORDS: gendered_words
#
#
# MODEL: Not debiased model
# ('maschile', 0.10207446962594988)
#
# MODEL: Debiased model single
# ('femminile', 0.008314610459637994)
#
# MODEL: Debiased model sum
# ('femminile', 0.023737202771007992)
#
# MODEL: Debiased model pca
# ('padre', 0.04696696251630783)
#
#
# GROUP OF WORDS: female_stereotypes
#
#
# MODEL: Not debiased model
# ('silenzioso', 0.01594360191375016)
#
# MODEL: Debiased model single
# ('silenzioso', 0.007240966334939092)
#
# MODEL: Debiased model sum
# ('delicato', 0.0170808790251612)
#
# MODEL: Debiased model pca
# ('sensibile', 0.03843159824609754)
#
#
# GROUP OF WORDS: male_stereotypes
#
#
# MODEL: Not debiased model
# ('ambizioso', 0.023078519944101594)
#
# MODEL: Debiased model single
# ('saggio', 0.005208798125386327)
#
# MODEL: Debiased model sum
# ('intollerante', 0.0170808790251612)
#
# MODEL: Debiased model pca
# ('forte', 0.03843159824609754)
#
#
# YEAR: 1968_1985
# HBox(children=(HTML(value='Passing group of words'), FloatProgress(value=0.0, max=12.0), HTML(value='')))
# GROUP OF WORDS: adj_appearence
#
#
# MODEL: Not debiased model
# ('brutto', 0.05616789534687999)
#
# MODEL: Debiased model single
# ('magro', 0.005951637960970313)
#
# MODEL: Debiased model sum
# ('magro', 0.027926203981041953)
#
# MODEL: Debiased model pca
# ('piacevole', 0.050618596747517564)
#
#
# GROUP OF WORDS: family
#
#
# MODEL: Not debiased model
# ('bambino', 0.16640051901340486)
#
# MODEL: Debiased model single
# ('matrimonio', 1.471489663451564e-08)
#
# MODEL: Debiased model sum
# ('matrimonio', 0.03363258354365828)
#
# MODEL: Debiased model pca
# ('matrimonio', 0.02690003253519546)
#
#
# GROUP OF WORDS: career
#
#
# MODEL: Not debiased model
# ('capo', 0.0022651735227555148)
#
# MODEL: Debiased model single
# ('potere', 0.004747527278959662)
#
# MODEL: Debiased model sum
# ('denaro', 0.027800564840435915)
#
# MODEL: Debiased model pca
# ('ambizione', 0.051518983021378584)
#
#
# GROUP OF WORDS: rage
#
#
# MODEL: Not debiased model
# ('odioso', 0.034859059005975745)
#
# MODEL: Debiased model single
# ('aggressivo', 0.005336591415107117)
#
# MODEL: Debiased model sum
# ('crudele', 0.027800564840435915)
#
# MODEL: Debiased model pca
# ('brutale', 0.050618596747517564)
#
#
# GROUP OF WORDS: kindness
#
#
# MODEL: Not debiased model
# ('gentile', 0.04863908812403678)
#
# MODEL: Debiased model single
# ('sensibile', 0.004747528582811245)
#
# MODEL: Debiased model sum
# ('buono', 0.026683877035975412)
#
# MODEL: Debiased model pca
# ('gentile', 0.0523066598922014)
#
#
# GROUP OF WORDS: intelligence
#
#
# MODEL: Not debiased model
# ('intelligente', 0.08782263472676277)
#
# MODEL: Debiased model single
# ('saggio', 0.005336592346429803)
#
# MODEL: Debiased model sum
# ('saggio', 0.028042264655232407)
#
# MODEL: Debiased model pca
# ('saggio', 0.049322089180350304)
#
#
# GROUP OF WORDS: dumbness
#
#
# MODEL: Not debiased model
# ('isterico', 0.04333236142992977)
#
# MODEL: Debiased model single
# ('illogico', 0.005951640196144581)
#
# MODEL: Debiased model sum
# ('isterico', 0.029082101210951894)
#
# MODEL: Debiased model pca
# ('illogico', 0.057671090587973595)
#
#
# GROUP OF WORDS: active
#
#
# MODEL: Not debiased model
# ('sicuro', 0.018191793560981745)
#
# MODEL: Debiased model single
# ('ambizioso', 0.004747528582811245)
#
# MODEL: Debiased model sum
# ('forte', 0.031842565536499)
#
# MODEL: Debiased model pca
# ('forte', 0.049322089180350304)
#
#
# GROUP OF WORDS: passive
#
#
# MODEL: Not debiased model
# ('silenzioso', 0.012300987541675523)
#
# MODEL: Debiased model single
# ('insicuro', 0.004747528582811245)
#
# MODEL: Debiased model sum
# ('timido', 0.029082101210951894)
#
# MODEL: Debiased model pca
# ('timido', 0.055488599464297295)
#
#
# GROUP OF WORDS: gendered_words
#
#
# MODEL: Not debiased model
# ('maschile', 0.14369957149028778)
#
# MODEL: Debiased model single
# ('nonno', 0.0009385278448462708)
#
# MODEL: Debiased model sum
# ('nonno', 0.019312879815697626)
#
# MODEL: Debiased model pca
# ('nonno', 0.05470092855393893)
#
#
# GROUP OF WORDS: female_stereotypes
#
#
# MODEL: Not debiased model
# ('gentile', 0.04863908812403678)
#
# MODEL: Debiased model single
# ('illogico', 0.005951640196144581)
#
# MODEL: Debiased model sum
# ('silenzioso', 0.029082101210951894)
#
# MODEL: Debiased model pca
# ('bello', 0.0523066598922014)
#
#
# GROUP OF WORDS: male_stereotypes
#
#
# MODEL: Not debiased model
# ('intelligente', 0.08782263472676277)
#
# MODEL: Debiased model single
# ('saggio', 0.005336592346429803)
#
# MODEL: Debiased model sum
# ('crudele', 0.027800564840435915)
#
# MODEL: Debiased model pca
# ('saggio', 0.049322089180350304)
#
#
# YEAR: 1985_2000
# HBox(children=(HTML(value='Passing group of words'), FloatProgress(value=0.0, max=12.0), HTML(value='')))
# GROUP OF WORDS: adj_appearence
#
#
# MODEL: Not debiased model
# ('splendido', 0.05066542923450465)
#
# MODEL: Debiased model single
# ('rozzo', 0.00464373100548976)
#
# MODEL: Debiased model sum
# ('rozzo', 0.01789615377783771)
#
# MODEL: Debiased model pca
# ('rozzo', 0.03807597104460003)
#
#
# GROUP OF WORDS: family
#
#
# MODEL: Not debiased model
# ('matrimonio', 0.07286201417446136)
#
# MODEL: Debiased model single
# ('matrimonio', 4.339963199928576e-08)
#
# MODEL: Debiased model sum
# ('matrimonio', 0.010125575959682442)
#
# MODEL: Debiased model pca
# ('matrimonio', 0.012361686490476198)
#
#
# GROUP OF WORDS: career
#
#
# MODEL: Not debiased model
# ('capo', 0.1179308181628585)
#
# MODEL: Debiased model single
# ('onorevole', 0.001222359947860241)
#
# MODEL: Debiased model sum
# ('onorevole', 0.01789615377783771)
#
# MODEL: Debiased model pca
# ('lavoro', 0.040664596110582374)
#
#
# GROUP OF WORDS: rage
#
#
# MODEL: Not debiased model
# ('brutale', 0.015967693179845782)
#
# MODEL: Debiased model single
# ('aggressivo', 0.008775549568235785)
#
# MODEL: Debiased model sum
# ('brutale', 0.01468264609575265)
#
# MODEL: Debiased model pca
# ('aggressivo', 0.03636315781623123)
#
#
# GROUP OF WORDS: kindness
#
#
# MODEL: Not debiased model
# ('bravo', 0.004278705269098293)
#
# MODEL: Debiased model single
# ('sensibile', 0.00464373100548976)
#
# MODEL: Debiased model sum
# ('bravo', 0.01468264609575265)
#
# MODEL: Debiased model pca
# ('delicato', 0.03954968526959424)
#
#
# GROUP OF WORDS: intelligence
#
#
# MODEL: Not debiased model
# ('saggio', 0.022935157269239448)
#
# MODEL: Debiased model single
# ('studioso', 0.009949654527008467)
#
# MODEL: Debiased model sum
# ('intelligente', 0.01473097354173647)
#
# MODEL: Debiased model pca
# ('serio', 0.040437642484903336)
#
#
# GROUP OF WORDS: dumbness
#
#
# MODEL: Not debiased model
# ('stupido', 0.017806877940893195)
#
# MODEL: Debiased model single
# ('illogico', 0.0023377997800708705)
#
# MODEL: Debiased model sum
# ('illogico', 0.01473097354173647)
#
# MODEL: Debiased model pca
# ('illogico', 0.040664596110582374)
#
#
# GROUP OF WORDS: active
#
#
# MODEL: Not debiased model
# ('sicuro', 0.002875342592597002)
#
# MODEL: Debiased model single
# ('forte', 0.009998333640396595)
#
# MODEL: Debiased model sum
# ('ambizioso', 0.01468264609575265)
#
# MODEL: Debiased model pca
# ('ambizioso', 0.0434258686378598)
#
#
# GROUP OF WORDS: passive
#
#
# MODEL: Not debiased model
# ('silenzioso', 0.08099380880594254)
#
# MODEL: Debiased model single
# ('timido', 4.824940115211174e-05)
#
# MODEL: Debiased model sum
# ('timido', 0.01789615377783771)
#
# MODEL: Debiased model pca
# ('timido', 0.040664596110582374)
#
#
# GROUP OF WORDS: gendered_words
#
#
# MODEL: Not debiased model
# ('maschile', 0.12590542212128636)
#
# MODEL: Debiased model single
# ('nonna', 0.021610839292407036)
#
# MODEL: Debiased model sum
# ('nonno', 0.008618906140327343)
#
# MODEL: Debiased model pca
# ('nonna', 0.052716925367713)
#
#
# GROUP OF WORDS: female_stereotypes
#
#
# MODEL: Not debiased model
# ('silenzioso', 0.08099380880594254)
#
# MODEL: Debiased model single
# ('sensibile', 0.00464373100548976)
#
# MODEL: Debiased model sum
# ('frivolo', 0.01473097354173647)
#
# MODEL: Debiased model pca
# ('delicato', 0.03954968526959424)
#
#
# GROUP OF WORDS: male_stereotypes
#
#
# MODEL: Not debiased model
# ('crudele', 0.01751024425029757)
#
# MODEL: Debiased model single
# ('forte', 0.009998333640396595)
#
# MODEL: Debiased model sum
# ('intelligente', 0.01473097354173647)
#
# MODEL: Debiased model pca
# ('razionale', 0.0434258686378598)
#
#
# YEAR: 2000_2020
# HBox(children=(HTML(value='Passing group of words'), FloatProgress(value=0.0, max=12.0), HTML(value='')))
# GROUP OF WORDS: adj_appearence
#
#
# MODEL: Not debiased model
# ('splendido', 0.006678805407136668)
#
# MODEL: Debiased model single
# ('frivolo', 0.0013397276401518887)
#
# MODEL: Debiased model sum
# ('rozzo', 0.006914766132831707)
#
# MODEL: Debiased model pca
# ('rozzo', 0.007583683356642723)
#
#
# GROUP OF WORDS: family
#
#
# MODEL: Not debiased model
# ('accudire', 0.12301618522033098)
#
# MODEL: Debiased model single
# ('matrimonio', 0.0074775189161300215)
#
# MODEL: Debiased model sum
# ('matrimonio', 0.0016129970550537998)
#
# MODEL: Debiased model pca
# ('matrimonio', 0.0022892255336045553)
#
#
# GROUP OF WORDS: career
#
#
# MODEL: Not debiased model
# ('ambizione', 0.0026756316423415805)
#
# MODEL: Debiased model single
# ('potere', 0.0013397376984357612)
#
# MODEL: Debiased model sum
# ('capo', 0.006914766132831707)
#
# MODEL: Debiased model pca
# ('capo', 0.007583683356642723)
#
#
# GROUP OF WORDS: rage
#
#
# MODEL: Not debiased model
# ('odioso', 0.15286566242575642)
#
# MODEL: Debiased model single
# ('cattivo', 0.0013397376984357612)
#
# MODEL: Debiased model sum
# ('intollerante', 0.006914766132831707)
#
# MODEL: Debiased model pca
# ('intollerante', 0.007583683356642723)
#
#
# GROUP OF WORDS: kindness
#
#
# MODEL: Not debiased model
# ('premuroso', 0.07302685305476195)
#
# MODEL: Debiased model single
# ('sensibile', 0.0013397250324487242)
#
# MODEL: Debiased model sum
# ('delicato', 0.006914766132831596)
#
# MODEL: Debiased model pca
# ('buono', 0.0075836818665266925)
#
#
# GROUP OF WORDS: intelligence
#
#
# MODEL: Not debiased model
# ('saggio', 0.01988909812644124)
#
# MODEL: Debiased model single
# ('razionale', 0.0013397276401518887)
#
# MODEL: Debiased model sum
# ('razionale', 0.006914760544896148)
#
# MODEL: Debiased model pca
# ('razionale', 0.007583683356642723)
#
#
# GROUP OF WORDS: dumbness
#
#
# MODEL: Not debiased model
# ('stupido', 0.01784309688955546)
#
# MODEL: Debiased model single
# ('superficiale', 0.0013397276401518887)
#
# MODEL: Debiased model sum
# ('superficiale', 0.006914766132831707)
#
# MODEL: Debiased model pca
# ('superficiale', 0.007583683356642723)
#
#
# GROUP OF WORDS: active
#
#
# MODEL: Not debiased model
# ('assertivo', 0.01759351640939713)
#
# MODEL: Debiased model single
# ('forte', 0.0013397276401518887)
#
# MODEL: Debiased model sum
# ('sicuro', 0.006914766132831707)
#
# MODEL: Debiased model pca
# ('sicuro', 0.007583683356642723)
#
#
# GROUP OF WORDS: passive
#
#
# MODEL: Not debiased model
# ('silenzioso', 0.10449921935796741)
#
# MODEL: Debiased model single
# ('timido', 0.0013397276401518887)
#
# MODEL: Debiased model sum
# ('silenzioso', 0.006914766132831707)
#
# MODEL: Debiased model pca
# ('timido', 0.007583683356642723)
#
#
# GROUP OF WORDS: gendered_words
#
#
# MODEL: Not debiased model
# ('maschile', 0.1733801264315844)
#
# MODEL: Debiased model single
# ('femminile', 0.015545826405286789)
#
# MODEL: Debiased model sum
# ('nonno', 0.034099462628364496)
#
# MODEL: Debiased model pca
# ('nonno', 0.03617947101593033)
#
#
# GROUP OF WORDS: female_stereotypes
#
#
# MODEL: Not debiased model
# ('silenzioso', 0.10449921935796741)
#
# MODEL: Debiased model single
# ('superficiale', 0.0013397276401518887)
#
# MODEL: Debiased model sum
# ('superficiale', 0.006914766132831707)
#
# MODEL: Debiased model pca
# ('superficiale', 0.007583683356642723)
#
#
# GROUP OF WORDS: male_stereotypes
#
#
# MODEL: Not debiased model
# ('saggio', 0.01988909812644124)
#
# MODEL: Debiased model single
# ('razionale', 0.0013397276401518887)
#
# MODEL: Debiased model sum
# ('intollerante', 0.006914766132831707)
#
# MODEL: Debiased model pca
# ('intollerante', 0.007583683356642723)
