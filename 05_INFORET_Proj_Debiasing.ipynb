# %% [markdown]
# # INFORMATION RETRIEVAL PROJECT

# %% [markdown]
# ---
# ## Gender stereotypes in parliamentary speeches
#
# In word embedding models, each word is assigned to a high-dimensional vector such that the geometry of the vectors captures semantic relations between the words – e.g. vectors being closer together has been shown to correspond to more similar words. Recent works in machine learning demonstrate that word embeddings also capture common stereotypes, as these stereotypes are likely to be present, even if subtly, in the large corpora of training texts. These stereotypes are automatically learned by the embedding algorithm and could be problematic in many context if the embedding is then used for sensitive applications such as search rankings, product recommendations, or translations. An important direction of research is on developing algorithms to debias the word embeddings.
#
# This project aims to use the word embeddings to study historical trends – specifically trends in the gender and ethnic stereotypes in the Italian parliamentary speeches from 1948 to 2020.

# %%
import numpy as np
import pandas as pd
import gensim
from gensim.models import KeyedVectors
from gensim.models import Word2Vec
import os
from collections import defaultdict, OrderedDict
from tqdm.auto import tqdm

from INFORET_project import load_embed_model
# import matplotlib.pylab as plt
pd.set_option("display.max_rows", 100, "display.max_columns", 100)

# %%
from INFORET_project import YEARS

# %%
YEARS
# Out:
# ['1948_1968', '1968_1985', '1985_2000', '2000_2020']

# %%
model = load_embed_model(YEARS[0])

# %%
model = load_embed_model(YEARS[1])

# %%
model = load_embed_model(YEARS[2])

# %%
model = load_embed_model(YEARS[3])

# %% [markdown]
# # 5. DEBIASING WORDS AND ASSESSING EAB

# %%
from INFORET_project import Debias
from INFORET_project.data import gendered_neutral_words

# %%
d = Debias(model.wv, definitional_pairs=['uomo','donna'],
                              identify_direction='single')
debiased_model_single = d.hard_debias(equality_sets=gendered_neutral_words['equality_sets'])

# %%
d = Debias(model.wv, definitional_pairs=['uomo','donna'],
                              identify_direction='sum')
debiased_model_sum = d.hard_debias(equality_sets=gendered_neutral_words['equality_sets'])

# %%
d = Debias(model.wv, definitional_pairs=['uomo','donna'], identify_direction='pca')
debiased_model_pca = d.hard_debias(equality_sets=gendered_neutral_words['equality_sets'])

# %% [markdown]
# ---

# %%
from INFORET_project.data import gendered_neutral_words
from INFORET_project import EAB
from INFORET_project import WORDS_GROUP

# %% [markdown]
# Print only the top biased words to see whether the bias is reduced when using debiased models

# %%
# averaged EAB version

for year in tqdm(YEARS,
                 desc='Passing years'):
    print(f'\nYEAR: {year}')
    model = load_embed_model(year)
    
    for word in tqdm(WORDS_GROUP,
                     desc='Passing group of words'):
        print(f'\n\nGROUP OF WORDS: {word}\n')

        print('\nMODEL: Not debiased model')
        score = EAB(model.wv,
                    use_avg_gender=True,
                    type_most_similar = 'cosmul')
        top_bias = score.get_top_bias(pred_positive_word=word, verbose=False)[0]
        print( (top_bias[0], abs(top_bias[1][0] - top_bias[1][1])) )
        
        for deb_type in ['single', 'sum', 'pca']:
            d = Debias(model.wv, definitional_pairs=['uomo','donna'],
                              identify_direction=deb_type)
            debiased_model = d.hard_debias(equality_sets=gendered_neutral_words['equality_sets'])
            
            score = EAB(debiased_model,
                        use_avg_gender=True,
                        type_most_similar = 'cosmul')
            print(f'\nMODEL: Debiased model {deb_type}')
            top_bias = score.get_top_bias(pred_positive_word=word, verbose=False)[0]
            print( (top_bias[0], abs(top_bias[1][0] - top_bias[1][1])) )
# Out:
# HBox(children=(HTML(value='Passing years'), FloatProgress(value=0.0, max=4.0), HTML(value='')))
# YEAR: 1948_1968
# HBox(children=(HTML(value='Passing group of words'), FloatProgress(value=0.0, max=12.0), HTML(value='')))
# GROUP OF WORDS: adj_appearence
#
#
# MODEL: Not debiased model
# ('grasso', 0.06127673238515857)
#
# MODEL: Debiased model single
# ('splendido', 0.331249711662531)
#
# MODEL: Debiased model sum
# ('bello', 0.021406903862953186)
#
# MODEL: Debiased model pca
# ('brutto', 0.3139020971953869)
#
#
# GROUP OF WORDS: family
#
#
# MODEL: Not debiased model
# ('bambino', 0.04381868690252305)
#
# MODEL: Debiased model single
# ('genitore', 0.3135473936796188)
#
# MODEL: Debiased model sum
# ('matrimonio', 0.03230702877044678)
#
# MODEL: Debiased model pca
# ('bambino', 0.2875015281140805)
#
#
# GROUP OF WORDS: career
#
#
# MODEL: Not debiased model
# ('capo', 0.0394399270415306)
#
# MODEL: Debiased model single
# ('capo', 0.37785068228840824)
#
# MODEL: Debiased model sum
# ('potere', 0.004791694879531849)
#
# MODEL: Debiased model pca
# ('capo', 0.35457774773240086)
#
#
# GROUP OF WORDS: rage
#
#
# MODEL: Not debiased model
# ('aggressivo', 0.0696475218981504)
#
# MODEL: Debiased model single
# ('cattivo', 0.3821953348815441)
#
# MODEL: Debiased model sum
# ('crudele', 0.016688188910484347)
#
# MODEL: Debiased model pca
# ('cattivo', 0.3552774049341679)
#
#
# GROUP OF WORDS: kindness
#
#
# MODEL: Not debiased model
# ('bravo', 0.008589015901088737)
#
# MODEL: Debiased model single
# ('bravo', 0.3053207993507386)
#
# MODEL: Debiased model sum
# ('gentile', 0.03765640109777452)
#
# MODEL: Debiased model pca
# ('buono', 0.35780785158276557)
#
#
# GROUP OF WORDS: intelligence
#
#
# MODEL: Not debiased model
# ('studioso', 0.013190972805023238)
#
# MODEL: Debiased model single
# ('studioso', 0.3401478245854378)
#
# MODEL: Debiased model sum
# ('serio', 0.011082297563552834)
#
# MODEL: Debiased model pca
# ('studioso', 0.31884757801890373)
#
#
# GROUP OF WORDS: dumbness
#
#
# MODEL: Not debiased model
# ('isterico', 0.010038386285305012)
#
# MODEL: Debiased model single
# ('irrazionale', 0.35172420218586925)
#
# MODEL: Debiased model sum
# ('illogico', 0.004751181602478061)
#
# MODEL: Debiased model pca
# ('irrazionale', 0.3289808057248592)
#
#
# GROUP OF WORDS: active
#
#
# MODEL: Not debiased model
# ('ambizioso', 0.03679673746228218)
#
# MODEL: Debiased model single
# ('forte', 0.34658420160412784)
#
# MODEL: Debiased model sum
# ('sicuro', 0.009624013304710355)
#
# MODEL: Debiased model pca
# ('forte', 0.32293758168816566)
#
#
# GROUP OF WORDS: passive
#
#
# MODEL: Not debiased model
# ('silenzioso', 0.007643775641918149)
#
# MODEL: Debiased model single
# ('silenzioso', 0.37232842594385146)
#
# MODEL: Debiased model sum
# ('silenzioso', 0.03310382068157197)
#
# MODEL: Debiased model pca
# ('silenzioso', 0.33579672351479534)
#
#
# GROUP OF WORDS: gendered_words
#
#
# MODEL: Not debiased model
# ('maschile', 0.05958382487297059)
#
# MODEL: Debiased model single
# ('nonna', 0.03443689122796051)
#
# MODEL: Debiased model sum
# ('ragazza', 0.005924916267395108)
#
# MODEL: Debiased model pca
# ('nonna', 0.0)
#
#
# GROUP OF WORDS: female_stereotypes
#
#
# MODEL: Not debiased model
# ('silenzioso', 0.007643775641918149)
#
# MODEL: Debiased model single
# ('silenzioso', 0.37232842594385146)
#
# MODEL: Debiased model sum
# ('gentile', 0.03765640109777452)
#
# MODEL: Debiased model pca
# ('silenzioso', 0.33579672351479534)
#
#
# GROUP OF WORDS: male_stereotypes
#
#
# MODEL: Not debiased model
# ('intelligente', 0.04734245315194127)
#
# MODEL: Debiased model single
# ('razionale', 0.34207591190934183)
#
# MODEL: Debiased model sum
# ('crudele', 0.016688188910484347)
#
# MODEL: Debiased model pca
# ('crudele', 0.31656437888741495)
#
#
# YEAR: 1968_1985
# HBox(children=(HTML(value='Passing group of words'), FloatProgress(value=0.0, max=12.0), HTML(value='')))
# GROUP OF WORDS: adj_appearence
#
#
# MODEL: Not debiased model
# ('sensuale', 0.03292045444250108)
#
# MODEL: Debiased model single
# ('grasso', 0.3629248946905136)
#
# MODEL: Debiased model sum
# ('bello', 0.01601635217666625)
#
# MODEL: Debiased model pca
# ('grasso', 0.004736405611038219)
#
#
# GROUP OF WORDS: family
#
#
# MODEL: Not debiased model
# ('bambino', 0.05103850066661836)
#
# MODEL: Debiased model single
# ('figlio', 0.3157605163753032)
#
# MODEL: Debiased model sum
# ('bambino', 0.03485752195119857)
#
# MODEL: Debiased model pca
# ('famiglia', 0.020816104114055656)
#
#
# GROUP OF WORDS: career
#
#
# MODEL: Not debiased model
# ('presidente', 0.04962961599230764)
#
# MODEL: Debiased model single
# ('professionale', 0.3571805231273174)
#
# MODEL: Debiased model sum
# ('onorevole', 0.023849748820066463)
#
# MODEL: Debiased model pca
# ('onorevole', 0.017385783791542098)
#
#
# GROUP OF WORDS: rage
#
#
# MODEL: Not debiased model
# ('intollerante', 0.0602129846811294)
#
# MODEL: Debiased model single
# ('crudele', 0.3721710965037346)
#
# MODEL: Debiased model sum
# ('crudele', 0.013611772656440702)
#
# MODEL: Debiased model pca
# ('intollerante', 0.007931077480316184)
#
#
# GROUP OF WORDS: kindness
#
#
# MODEL: Not debiased model
# ('bravo', 0.03786450028419491)
#
# MODEL: Debiased model single
# ('bravo', 0.3747031211853027)
#
# MODEL: Debiased model sum
# ('gentile', 0.025506758689880338)
#
# MODEL: Debiased model pca
# ('gentile', 0.004366087913513117)
#
#
# GROUP OF WORDS: intelligence
#
#
# MODEL: Not debiased model
# ('studioso', 0.03357839286327363)
#
# MODEL: Debiased model single
# ('studioso', 0.3697554752230644)
#
# MODEL: Debiased model sum
# ('intelligente', 6.33239746093972e-05)
#
# MODEL: Debiased model pca
# ('intelligente', 0.0033009439706802035)
#
#
# GROUP OF WORDS: dumbness
#
#
# MODEL: Not debiased model
# ('stupido', 0.05983314961194991)
#
# MODEL: Debiased model single
# ('irrazionale', 0.3751224666833877)
#
# MODEL: Debiased model sum
# ('stupido', 0.003946280479431186)
#
# MODEL: Debiased model pca
# ('stupido', 0.003776538372039784)
#
#
# GROUP OF WORDS: active
#
#
# MODEL: Not debiased model
# ('ambizioso', 0.06336533427238467)
#
# MODEL: Debiased model single
# ('forte', 0.38046567142009735)
#
# MODEL: Debiased model sum
# ('ambizioso', 0.006481185555458069)
#
# MODEL: Debiased model pca
# ('sicuro', 0.011090308427810669)
#
#
# GROUP OF WORDS: passive
#
#
# MODEL: Not debiased model
# ('insicuro', 0.03633227422833446)
#
# MODEL: Debiased model single
# ('debole', 0.3645333662629127)
#
# MODEL: Debiased model sum
# ('silenzioso', 0.007885622978210438)
#
# MODEL: Debiased model pca
# ('silenzioso', 0.0010179221630096102)
#
#
# GROUP OF WORDS: gendered_words
#
#
# MODEL: Not debiased model
# ('madre', 0.08406004607677459)
#
# MODEL: Debiased model single
# ('nonno', 0.04025196060538294)
#
# MODEL: Debiased model sum
# ('nonna', 0.0)
#
# MODEL: Debiased model pca
# ('maschile', 0.005711221694946311)
#
#
# GROUP OF WORDS: female_stereotypes
#
#
# MODEL: Not debiased model
# ('frivolo', 0.054298542439937536)
#
# MODEL: Debiased model single
# ('debole', 0.3645333662629127)
#
# MODEL: Debiased model sum
# ('gentile', 0.025506758689880338)
#
# MODEL: Debiased model pca
# ('gentile', 0.004366087913513117)
#
#
# GROUP OF WORDS: male_stereotypes
#
#
# MODEL: Not debiased model
# ('intollerante', 0.0602129846811294)
#
# MODEL: Debiased model single
# ('crudele', 0.3721710965037346)
#
# MODEL: Debiased model sum
# ('intelligente', 6.33239746093972e-05)
#
# MODEL: Debiased model pca
# ('intelligente', 0.0033009439706802035)
#
#
# YEAR: 1985_2000
# HBox(children=(HTML(value='Passing group of words'), FloatProgress(value=0.0, max=12.0), HTML(value='')))
# GROUP OF WORDS: adj_appearence
#
#
# MODEL: Not debiased model
# ('frivolo', 0.06346932649612425)
#
# MODEL: Debiased model single
# ('grasso', 0.3786844291724265)
#
# MODEL: Debiased model sum
# ('grasso', 0.007533681392669689)
#
# MODEL: Debiased model pca
# ('bello', 0.2999991778284311)
#
#
# GROUP OF WORDS: family
#
#
# MODEL: Not debiased model
# ('bambino', 0.025714072585105885)
#
# MODEL: Debiased model single
# ('famiglia', 0.3828860007226468)
#
# MODEL: Debiased model sum
# ('bambino', 0.016521964967250835)
#
# MODEL: Debiased model pca
# ('famiglia', 0.32024010941386233)
#
#
# GROUP OF WORDS: career
#
#
# MODEL: Not debiased model
# ('capo', 0.012652518227696419)
#
# MODEL: Debiased model single
# ('professionale', 0.37201162241399294)
#
# MODEL: Debiased model sum
# ('professionale', 0.011811992526054416)
#
# MODEL: Debiased model pca
# ('professionale', 0.31129593886435036)
#
#
# GROUP OF WORDS: rage
#
#
# MODEL: Not debiased model
# ('cattivo', 0.04554537683725357)
#
# MODEL: Debiased model single
# ('brutale', 0.40025616548955445)
#
# MODEL: Debiased model sum
# ('cattivo', 0.009630040824413322)
#
# MODEL: Debiased model pca
# ('crudele', 0.3324172545224428)
#
#
# GROUP OF WORDS: kindness
#
#
# MODEL: Not debiased model
# ('bravo', 0.08703152537345887)
#
# MODEL: Debiased model single
# ('bravo', 0.38761478820815687)
#
# MODEL: Debiased model sum
# ('gentile', 0.031958910822868336)
#
# MODEL: Debiased model pca
# ('premuroso', 0.2795385543256998)
#
#
# GROUP OF WORDS: intelligence
#
#
# MODEL: Not debiased model
# ('studioso', 0.12164089828729627)
#
# MODEL: Debiased model single
# ('razionale', 0.4059576522558928)
#
# MODEL: Debiased model sum
# ('serio', 0.006397330760955833)
#
# MODEL: Debiased model pca
# ('saggio', 0.28489355482161044)
#
#
# GROUP OF WORDS: dumbness
#
#
# MODEL: Not debiased model
# ('stupido', 0.018399919569492273)
#
# MODEL: Debiased model single
# ('stupido', 0.4071288626641036)
#
# MODEL: Debiased model sum
# ('illogico', 0.0038350850343704113)
#
# MODEL: Debiased model pca
# ('stupido', 0.34164156056940553)
#
#
# GROUP OF WORDS: active
#
#
# MODEL: Not debiased model
# ('sicuro', 0.03558809757232667)
#
# MODEL: Debiased model single
# ('forte', 0.4026810672134162)
#
# MODEL: Debiased model sum
# ('ambizioso', 0.013206732273101762)
#
# MODEL: Debiased model pca
# ('forte', 0.33560822792351247)
#
#
# GROUP OF WORDS: passive
#
#
# MODEL: Not debiased model
# ('passivo', 0.03018939048051833)
#
# MODEL: Debiased model single
# ('debole', 0.3835276436060667)
#
# MODEL: Debiased model sum
# ('debole', 0.021852147579193126)
#
# MODEL: Debiased model pca
# ('debole', 0.3251947078853846)
#
#
# GROUP OF WORDS: gendered_words
#
#
# MODEL: Not debiased model
# ('ragazza', 0.02867603600025176)
#
# MODEL: Debiased model single
# ('nonno', 0.007805719133466504)
#
# MODEL: Debiased model sum
# ('ragazza', 0.0)
#
# MODEL: Debiased model pca
# ('nonno', 0.0)
#
#
# GROUP OF WORDS: female_stereotypes
#
#
# MODEL: Not debiased model
# ('passivo', 0.03018939048051833)
#
# MODEL: Debiased model single
# ('debole', 0.3835276436060667)
#
# MODEL: Debiased model sum
# ('gentile', 0.031958910822868336)
#
# MODEL: Debiased model pca
# ('bello', 0.2999991778284311)
#
#
# GROUP OF WORDS: male_stereotypes
#
#
# MODEL: Not debiased model
# ('razionale', 0.050117566436529176)
#
# MODEL: Debiased model single
# ('forte', 0.4026810672134162)
#
# MODEL: Debiased model sum
# ('intelligente', 0.01466667652130127)
#
# MODEL: Debiased model pca
# ('saggio', 0.28489355482161044)
#
#
# YEAR: 2000_2020
# HBox(children=(HTML(value='Passing group of words'), FloatProgress(value=0.0, max=12.0), HTML(value='')))
# GROUP OF WORDS: adj_appearence
#
#
# MODEL: Not debiased model
# ('brutto', 0.03416837677359583)
#
# MODEL: Debiased model single
# ('bello', 0.3816258057486266)
#
# MODEL: Debiased model sum
# ('bello', 0.04264675229787823)
#
# MODEL: Debiased model pca
# ('splendido', 0.6485581190325319)
#
#
# GROUP OF WORDS: family
#
#
# MODEL: Not debiased model
# ('bambino', 0.03165259659290315)
#
# MODEL: Debiased model single
# ('famiglia', 0.40286856140010063)
#
# MODEL: Debiased model sum
# ('matrimonio', 0.052633196115493774)
#
# MODEL: Debiased model pca
# ('matrimonio', 0.668773240223527)
#
#
# GROUP OF WORDS: career
#
#
# MODEL: Not debiased model
# ('capo', 0.0712145067751408)
#
# MODEL: Debiased model single
# ('professionale', 0.3887537821661681)
#
# MODEL: Debiased model sum
# ('presidente', 0.004960994422435749)
#
# MODEL: Debiased model pca
# ('onorevole', 0.6859465164132417)
#
#
# GROUP OF WORDS: rage
#
#
# MODEL: Not debiased model
# ('intollerante', 0.058555851876735676)
#
# MODEL: Debiased model single
# ('intollerante', 0.4310970946680755)
#
# MODEL: Debiased model sum
# ('brutale', 0.032850891351699885)
#
# MODEL: Debiased model pca
# ('brutale', 0.7095310715027154)
#
#
# GROUP OF WORDS: kindness
#
#
# MODEL: Not debiased model
# ('premuroso', 0.08352464735507958)
#
# MODEL: Debiased model single
# ('bravo', 0.4194845854770392)
#
# MODEL: Debiased model sum
# ('gentile', 0.0294449001550674)
#
# MODEL: Debiased model pca
# ('gentile', 0.6125980463810266)
#
#
# GROUP OF WORDS: intelligence
#
#
# MODEL: Not debiased model
# ('studioso', 0.08405009955167772)
#
# MODEL: Debiased model single
# ('intelligente', 0.4421687885653228)
#
# MODEL: Debiased model sum
# ('saggio', 0.031765732169151295)
#
# MODEL: Debiased model pca
# ('studioso', 0.6982009411789477)
#
#
# GROUP OF WORDS: dumbness
#
#
# MODEL: Not debiased model
# ('stupido', 0.014228223264217355)
#
# MODEL: Debiased model single
# ('stupido', 0.43973419810645287)
#
# MODEL: Debiased model sum
# ('illogico', 0.005150511860847473)
#
# MODEL: Debiased model pca
# ('isterico', 0.7056803342886269)
#
#
# GROUP OF WORDS: active
#
#
# MODEL: Not debiased model
# ('assertivo', 0.049580627679824796)
#
# MODEL: Debiased model single
# ('sicuro', 0.4418687745463103)
#
# MODEL: Debiased model sum
# ('sicuro', 0.003139081597328175)
#
# MODEL: Debiased model pca
# ('assertivo', 0.709695861954242)
#
#
# GROUP OF WORDS: passive
#
#
# MODEL: Not debiased model
# ('insicuro', 0.07787061333656306)
#
# MODEL: Debiased model single
# ('debole', 0.43133549238555136)
#
# MODEL: Debiased model sum
# ('silenzioso', 0.004671216011047363)
#
# MODEL: Debiased model pca
# ('insicuro', 0.6852110584266484)
#
#
# GROUP OF WORDS: gendered_words
#
#
# MODEL: Not debiased model
# ('femminile', 0.030746971070766405)
#
# MODEL: Debiased model single
# ('nonno', 0.0)
#
# MODEL: Debiased model sum
# ('nonno', 0.0)
#
# MODEL: Debiased model pca
# ('nonna', 0.0)
#
#
# GROUP OF WORDS: female_stereotypes
#
#
# MODEL: Not debiased model
# ('insicuro', 0.07787061333656306)
#
# MODEL: Debiased model single
# ('bello', 0.3816258057486266)
#
# MODEL: Debiased model sum
# ('bello', 0.04264675229787823)
#
# MODEL: Debiased model pca
# ('gentile', 0.6125980463810266)
#
#
# GROUP OF WORDS: male_stereotypes
#
#
# MODEL: Not debiased model
# ('intollerante', 0.058555851876735676)
#
# MODEL: Debiased model single
# ('intollerante', 0.4310970946680755)
#
# MODEL: Debiased model sum
# ('saggio', 0.031765732169151295)
#
# MODEL: Debiased model pca
# ('assertivo', 0.709695861954242)

# %%
# not averaged EAB version

for year in tqdm(YEARS,
                 desc='Passing years'):
    print(f'\nYEAR: {year}')
    model = load_embed_model(year)
    
    for word in tqdm(WORDS_GROUP,
                     desc='Passing group of words'):
        print(f'\n\nGROUP OF WORDS: {word}\n')

        print('\nMODEL: Not debiased model')
        score = EAB(model.wv,
                    gender_female='donna',
                    gender_male='uomo',
                    type_most_similar = 'cosmul')
        top_bias = score.get_top_bias(pred_positive_word=word, verbose=False)[0]
        print( (top_bias[0], abs(top_bias[1][0] - top_bias[1][1])) )
        
        for deb_type in ['single', 'sum', 'pca']:
            d = Debias(model.wv, definitional_pairs=['uomo','donna'],
                              identify_direction=deb_type)
            debiased_model = d.hard_debias(equality_sets=gendered_neutral_words['equality_sets'])
            
            score = EAB(debiased_model,
                        gender_female='donna',
                        gender_male='uomo',
                        type_most_similar = 'cosmul')
            print(f'\nMODEL: Debiased model {deb_type}')
            top_bias = score.get_top_bias(pred_positive_word=word, verbose=False)[0]
            print( (top_bias[0], abs(top_bias[1][0] - top_bias[1][1])) )
# Out:
# HBox(children=(HTML(value='Passing years'), FloatProgress(value=0.0, max=4.0), HTML(value='')))
# YEAR: 1948_1968
# HBox(children=(HTML(value='Passing group of words'), FloatProgress(value=0.0, max=12.0), HTML(value='')))
# GROUP OF WORDS: adj_appearence
#
#
# MODEL: Not debiased model
# ('brutto', 0.02924209404736755)
#
# MODEL: Debiased model single
# ('rozzo', 0.017551195248961426)
#
# MODEL: Debiased model sum
# ('piacevole', 0.02327295523136863)
#
# MODEL: Debiased model pca
# ('rozzo', 0.03575541973114016)
#
#
# GROUP OF WORDS: family
#
#
# MODEL: Not debiased model
# ('accudire', 0.10531398877501488)
#
# MODEL: Debiased model single
# ('accudire', 0.0012819427996872967)
#
# MODEL: Debiased model sum
# ('accudire', 0.01660062503069648)
#
# MODEL: Debiased model pca
# ('accudire', 0.03742551654577242)
#
#
# GROUP OF WORDS: career
#
#
# MODEL: Not debiased model
# ('ambizione', 0.033331044763326656)
#
# MODEL: Debiased model single
# ('denaro', 0.01843912042677398)
#
# MODEL: Debiased model sum
# ('potere', 0.02327295523136863)
#
# MODEL: Debiased model pca
# ('capo', 0.03575541973114016)
#
#
# GROUP OF WORDS: rage
#
#
# MODEL: Not debiased model
# ('crudele', 0.02310821935534474)
#
# MODEL: Debiased model single
# ('intollerante', 0.017551195248961426)
#
# MODEL: Debiased model sum
# ('aggressivo', 0.02327295523136863)
#
# MODEL: Debiased model pca
# ('intollerante', 0.03575541973114016)
#
#
# GROUP OF WORDS: kindness
#
#
# MODEL: Not debiased model
# ('gentile', 0.03569187410175795)
#
# MODEL: Debiased model single
# ('buono', 0.01843912042677398)
#
# MODEL: Debiased model sum
# ('buono', 0.02327295523136863)
#
# MODEL: Debiased model pca
# ('sensibile', 0.03575541973114016)
#
#
# GROUP OF WORDS: intelligence
#
#
# MODEL: Not debiased model
# ('saggio', 0.020320691261440482)
#
# MODEL: Debiased model single
# ('saggio', 0.017551195248961426)
#
# MODEL: Debiased model sum
# ('intelligente', 0.02918542306870231)
#
# MODEL: Debiased model pca
# ('intelligente', 0.03955776505172248)
#
#
# GROUP OF WORDS: dumbness
#
#
# MODEL: Not debiased model
# ('isterico', 0.0804755762219429)
#
# MODEL: Debiased model single
# ('isterico', 0.01843912042677398)
#
# MODEL: Debiased model sum
# ('isterico', 0.02756850328296423)
#
# MODEL: Debiased model pca
# ('irrazionale', 0.03575541973114016)
#
#
# GROUP OF WORDS: active
#
#
# MODEL: Not debiased model
# ('ambizioso', 0.023078519944101594)
#
# MODEL: Debiased model single
# ('sicuro', 0.01843912042677398)
#
# MODEL: Debiased model sum
# ('sicuro', 0.02327295523136863)
#
# MODEL: Debiased model pca
# ('forte', 0.03575541973114016)
#
#
# GROUP OF WORDS: passive
#
#
# MODEL: Not debiased model
# ('silenzioso', 0.01594360191375016)
#
# MODEL: Debiased model single
# ('timido', 0.017551195248961426)
#
# MODEL: Debiased model sum
# ('insicuro', 0.02327295523136863)
#
# MODEL: Debiased model pca
# ('timido', 0.03575541973114016)
#
#
# GROUP OF WORDS: gendered_words
#
#
# MODEL: Not debiased model
# ('maschile', 0.10207446962594988)
#
# MODEL: Debiased model single
# ('femminile', 0.008314619400334733)
#
# MODEL: Debiased model sum
# ('femminile', 0.028288055397570067)
#
# MODEL: Debiased model pca
# ('nonna', 0.10296624377369878)
#
#
# GROUP OF WORDS: female_stereotypes
#
#
# MODEL: Not debiased model
# ('silenzioso', 0.01594360191375016)
#
# MODEL: Debiased model single
# ('debole', 0.017551195248961426)
#
# MODEL: Debiased model sum
# ('insicuro', 0.02327295523136863)
#
# MODEL: Debiased model pca
# ('sensibile', 0.03575541973114016)
#
#
# GROUP OF WORDS: male_stereotypes
#
#
# MODEL: Not debiased model
# ('ambizioso', 0.023078519944101594)
#
# MODEL: Debiased model single
# ('saggio', 0.017551195248961426)
#
# MODEL: Debiased model sum
# ('intollerante', 0.025568637810647554)
#
# MODEL: Debiased model pca
# ('forte', 0.03575541973114016)
#
#
# YEAR: 1968_1985
# HBox(children=(HTML(value='Passing group of words'), FloatProgress(value=0.0, max=12.0), HTML(value='')))
# GROUP OF WORDS: adj_appearence
#
#
# MODEL: Not debiased model
# ('brutto', 0.05616789534687999)
#
# MODEL: Debiased model single
# ('magro', 0.010845014639198736)
#
# MODEL: Debiased model sum
# ('magro', 0.025574414059519768)
#
# MODEL: Debiased model pca
# ('piacevole', 0.05172188170254233)
#
#
# GROUP OF WORDS: family
#
#
# MODEL: Not debiased model
# ('bambino', 0.16640051901340486)
#
# MODEL: Debiased model single
# ('matrimonio', 8.754432179181038e-09)
#
# MODEL: Debiased model sum
# ('matrimonio', 0.017241074144840107)
#
# MODEL: Debiased model pca
# ('matrimonio', 0.026900038495659917)
#
#
# GROUP OF WORDS: career
#
#
# MODEL: Not debiased model
# ('capo', 0.0022651735227555148)
#
# MODEL: Debiased model single
# ('potere', 0.009640903957188196)
#
# MODEL: Debiased model sum
# ('denaro', 0.025448774918913952)
#
# MODEL: Debiased model pca
# ('ambizione', 0.05262226797640335)
#
#
# GROUP OF WORDS: rage
#
#
# MODEL: Not debiased model
# ('odioso', 0.034859059005975745)
#
# MODEL: Debiased model single
# ('crudele', 0.010845014639198736)
#
# MODEL: Debiased model sum
# ('crudele', 0.025448774918913952)
#
# MODEL: Debiased model pca
# ('brutale', 0.05172188170254233)
#
#
# GROUP OF WORDS: kindness
#
#
# MODEL: Not debiased model
# ('gentile', 0.04863908812403678)
#
# MODEL: Debiased model single
# ('sensibile', 0.009640905261039667)
#
# MODEL: Debiased model sum
# ('buono', 0.02433208711445345)
#
# MODEL: Debiased model pca
# ('gentile', 0.053409944847226276)
#
#
# GROUP OF WORDS: intelligence
#
#
# MODEL: Not debiased model
# ('intelligente', 0.08782263472676277)
#
# MODEL: Debiased model single
# ('saggio', 0.010229969024658225)
#
# MODEL: Debiased model sum
# ('saggio', 0.025690474733710333)
#
# MODEL: Debiased model pca
# ('saggio', 0.05042537413537507)
#
#
# GROUP OF WORDS: dumbness
#
#
# MODEL: Not debiased model
# ('isterico', 0.04333236142992977)
#
# MODEL: Debiased model single
# ('illogico', 0.010845016874372893)
#
# MODEL: Debiased model sum
# ('isterico', 0.02673031128942971)
#
# MODEL: Debiased model pca
# ('illogico', 0.05877437554299836)
#
#
# GROUP OF WORDS: active
#
#
# MODEL: Not debiased model
# ('sicuro', 0.018191793560981745)
#
# MODEL: Debiased model single
# ('ambizioso', 0.009640905261039667)
#
# MODEL: Debiased model sum
# ('forte', 0.029490775614976927)
#
# MODEL: Debiased model pca
# ('forte', 0.05042537413537507)
#
#
# GROUP OF WORDS: passive
#
#
# MODEL: Not debiased model
# ('silenzioso', 0.012300987541675523)
#
# MODEL: Debiased model single
# ('insicuro', 0.009640905261039667)
#
# MODEL: Debiased model sum
# ('timido', 0.02673031128942971)
#
# MODEL: Debiased model pca
# ('timido', 0.05659188441932206)
#
#
# GROUP OF WORDS: gendered_words
#
#
# MODEL: Not debiased model
# ('maschile', 0.14369957149028778)
#
# MODEL: Debiased model single
# ('nonno', 0.003954848833382152)
#
# MODEL: Debiased model sum
# ('nonno', 0.016961089894175663)
#
# MODEL: Debiased model pca
# ('nonno', 0.055804213508963585)
#
#
# GROUP OF WORDS: female_stereotypes
#
#
# MODEL: Not debiased model
# ('gentile', 0.04863908812403678)
#
# MODEL: Debiased model single
# ('illogico', 0.010845016874372893)
#
# MODEL: Debiased model sum
# ('silenzioso', 0.02673031128942971)
#
# MODEL: Debiased model pca
# ('bello', 0.053409944847226276)
#
#
# GROUP OF WORDS: male_stereotypes
#
#
# MODEL: Not debiased model
# ('intelligente', 0.08782263472676277)
#
# MODEL: Debiased model single
# ('saggio', 0.010229969024658225)
#
# MODEL: Debiased model sum
# ('crudele', 0.025448774918913952)
#
# MODEL: Debiased model pca
# ('saggio', 0.05042537413537507)
#
#
# YEAR: 1985_2000
# HBox(children=(HTML(value='Passing group of words'), FloatProgress(value=0.0, max=12.0), HTML(value='')))
# GROUP OF WORDS: adj_appearence
#
#
# MODEL: Not debiased model
# ('splendido', 0.05066542923450465)
#
# MODEL: Debiased model single
# ('rozzo', 0.00570427570492027)
#
# MODEL: Debiased model sum
# ('rozzo', 0.01831345930695527)
#
# MODEL: Debiased model pca
# ('rozzo', 0.038520068116486006)
#
#
# GROUP OF WORDS: family
#
#
# MODEL: Not debiased model
# ('matrimonio', 0.07286201417446136)
#
# MODEL: Debiased model single
# ('matrimonio', 3.5949051513384234e-08)
#
# MODEL: Debiased model sum
# ('matrimonio', 0.010125575959682442)
#
# MODEL: Debiased model pca
# ('matrimonio', 0.01236168798059234)
#
#
# GROUP OF WORDS: career
#
#
# MODEL: Not debiased model
# ('capo', 0.1179308181628585)
#
# MODEL: Debiased model single
# ('onorevole', 0.00228290464729064)
#
# MODEL: Debiased model sum
# ('onorevole', 0.01831345930695527)
#
# MODEL: Debiased model pca
# ('lavoro', 0.04110869318246846)
#
#
# GROUP OF WORDS: rage
#
#
# MODEL: Not debiased model
# ('brutale', 0.015967693179845782)
#
# MODEL: Debiased model single
# ('aggressivo', 0.009836094267666295)
#
# MODEL: Debiased model sum
# ('intollerante', 0.015099951624870322)
#
# MODEL: Debiased model pca
# ('aggressivo', 0.03680725488811731)
#
#
# GROUP OF WORDS: kindness
#
#
# MODEL: Not debiased model
# ('bravo', 0.004278705269098293)
#
# MODEL: Debiased model single
# ('sensibile', 0.00570427570492027)
#
# MODEL: Debiased model sum
# ('bravo', 0.015099951624870322)
#
# MODEL: Debiased model pca
# ('delicato', 0.03999378234148021)
#
#
# GROUP OF WORDS: intelligence
#
#
# MODEL: Not debiased model
# ('saggio', 0.022935157269239448)
#
# MODEL: Debiased model single
# ('studioso', 0.011010199226438977)
#
# MODEL: Debiased model sum
# ('intelligente', 0.015148279070854143)
#
# MODEL: Debiased model pca
# ('serio', 0.04088173955678942)
#
#
# GROUP OF WORDS: dumbness
#
#
# MODEL: Not debiased model
# ('stupido', 0.017806877940893195)
#
# MODEL: Debiased model single
# ('illogico', 0.0033983444795012696)
#
# MODEL: Debiased model sum
# ('illogico', 0.015148279070854143)
#
# MODEL: Debiased model pca
# ('illogico', 0.04110869318246846)
#
#
# GROUP OF WORDS: active
#
#
# MODEL: Not debiased model
# ('sicuro', 0.002875342592597002)
#
# MODEL: Debiased model single
# ('forte', 0.011058878339827105)
#
# MODEL: Debiased model sum
# ('ambizioso', 0.015099951624870322)
#
# MODEL: Debiased model pca
# ('ambizioso', 0.04386996570974577)
#
#
# GROUP OF WORDS: passive
#
#
# MODEL: Not debiased model
# ('silenzioso', 0.08099380880594254)
#
# MODEL: Debiased model single
# ('timido', 0.0011087941005825108)
#
# MODEL: Debiased model sum
# ('timido', 0.01831345930695527)
#
# MODEL: Debiased model pca
# ('timido', 0.04110869318246846)
#
#
# GROUP OF WORDS: gendered_words
#
#
# MODEL: Not debiased model
# ('maschile', 0.12590542212128636)
#
# MODEL: Debiased model single
# ('nonna', 0.022671383991837546)
#
# MODEL: Debiased model sum
# ('nonna', 0.036822628974914506)
#
# MODEL: Debiased model pca
# ('nonna', 0.05316102243959908)
#
#
# GROUP OF WORDS: female_stereotypes
#
#
# MODEL: Not debiased model
# ('silenzioso', 0.08099380880594254)
#
# MODEL: Debiased model single
# ('sensibile', 0.00570427570492027)
#
# MODEL: Debiased model sum
# ('frivolo', 0.015148279070854143)
#
# MODEL: Debiased model pca
# ('delicato', 0.03999378234148021)
#
#
# GROUP OF WORDS: male_stereotypes
#
#
# MODEL: Not debiased model
# ('crudele', 0.01751024425029757)
#
# MODEL: Debiased model single
# ('forte', 0.011058878339827105)
#
# MODEL: Debiased model sum
# ('intelligente', 0.015148279070854143)
#
# MODEL: Debiased model pca
# ('razionale', 0.04386996570974577)
#
#
# YEAR: 2000_2020
# HBox(children=(HTML(value='Passing group of words'), FloatProgress(value=0.0, max=12.0), HTML(value='')))
# GROUP OF WORDS: adj_appearence
#
#
# MODEL: Not debiased model
# ('splendido', 0.006678805407136668)
#
# MODEL: Debiased model single
# ('frivolo', 0.016938852146268002)
#
# MODEL: Debiased model sum
# ('rozzo', 0.0023882292211055978)
#
# MODEL: Debiased model pca
# ('rozzo', 0.005445801839232378)
#
#
# GROUP OF WORDS: family
#
#
# MODEL: Not debiased model
# ('accudire', 0.12301618522033098)
#
# MODEL: Debiased model single
# ('matrimonio', 0.021910957992076985)
#
# MODEL: Debiased model sum
# ('matrimonio', 0.002913539856672309)
#
# MODEL: Debiased model pca
# ('matrimonio', 0.00015134401619432136)
#
#
# GROUP OF WORDS: career
#
#
# MODEL: Not debiased model
# ('ambizione', 0.0026756316423415805)
#
# MODEL: Debiased model single
# ('potere', 0.01918617561459557)
#
# MODEL: Debiased model sum
# ('capo', 0.0023882292211055978)
#
# MODEL: Debiased model pca
# ('capo', 0.005445801839232378)
#
#
# GROUP OF WORDS: rage
#
#
# MODEL: Not debiased model
# ('odioso', 0.15286566242575642)
#
# MODEL: Debiased model single
# ('aggressivo', 0.014013432338833898)
#
# MODEL: Debiased model sum
# ('intollerante', 0.0023882292211055978)
#
# MODEL: Debiased model pca
# ('intollerante', 0.005445801839232378)
#
#
# GROUP OF WORDS: kindness
#
#
# MODEL: Not debiased model
# ('premuroso', 0.07302685305476195)
#
# MODEL: Debiased model single
# ('sensibile', 0.018760296329855985)
#
# MODEL: Debiased model sum
# ('delicato', 0.0023882292211054867)
#
# MODEL: Debiased model pca
# ('buono', 0.0054458003491162366)
#
#
# GROUP OF WORDS: intelligence
#
#
# MODEL: Not debiased model
# ('saggio', 0.01988909812644124)
#
# MODEL: Debiased model single
# ('razionale', 0.021007619798183552)
#
# MODEL: Debiased model sum
# ('razionale', 0.00238822363317015)
#
# MODEL: Debiased model pca
# ('razionale', 0.005445801839232378)
#
#
# GROUP OF WORDS: dumbness
#
#
# MODEL: Not debiased model
# ('stupido', 0.01784309688955546)
#
# MODEL: Debiased model single
# ('superficiale', 0.01918617561459557)
#
# MODEL: Debiased model sum
# ('superficiale', 0.0023882292211055978)
#
# MODEL: Debiased model pca
# ('superficiale', 0.005445801839232378)
#
#
# GROUP OF WORDS: active
#
#
# MODEL: Not debiased model
# ('assertivo', 0.01759351640939713)
#
# MODEL: Debiased model single
# ('assertivo', 0.01785922423005115)
#
# MODEL: Debiased model sum
# ('sicuro', 0.0023882292211055978)
#
# MODEL: Debiased model pca
# ('sicuro', 0.005445801839232378)
#
#
# GROUP OF WORDS: passive
#
#
# MODEL: Not debiased model
# ('silenzioso', 0.10449921935796741)
#
# MODEL: Debiased model single
# ('timido', 0.01785922423005115)
#
# MODEL: Debiased model sum
# ('silenzioso', 0.0023882292211055978)
#
# MODEL: Debiased model pca
# ('timido', 0.005445801839232378)
#
#
# GROUP OF WORDS: gendered_words
#
#
# MODEL: Not debiased model
# ('maschile', 0.1733801264315844)
#
# MODEL: Debiased model single
# ('maschile', 0.026091423630714483)
#
# MODEL: Debiased model sum
# ('nonna', 0.027184706926345892)
#
# MODEL: Debiased model pca
# ('nonno', 0.034041589498519875)
#
#
# GROUP OF WORDS: female_stereotypes
#
#
# MODEL: Not debiased model
# ('silenzioso', 0.10449921935796741)
#
# MODEL: Debiased model single
# ('superficiale', 0.01918617561459557)
#
# MODEL: Debiased model sum
# ('superficiale', 0.0023882292211055978)
#
# MODEL: Debiased model pca
# ('superficiale', 0.005445801839232378)
#
#
# GROUP OF WORDS: male_stereotypes
#
#
# MODEL: Not debiased model
# ('saggio', 0.01988909812644124)
#
# MODEL: Debiased model single
# ('assertivo', 0.01785922423005115)
#
# MODEL: Debiased model sum
# ('intollerante', 0.0023882292211055978)
#
# MODEL: Debiased model pca
# ('intollerante', 0.005445801839232378)
